# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "F:/camp/hw/hw6/starter_code/output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
type(cities)
api_key = 'e2f1672a4c40921c12c7fb4ce6e788ab'
# http://api.openweathermap.org/data/2.5/weather?q=otane&appid=e2f1672a4c40921c12c7fb4ce6e788ab

# %%
# Make a request for each of the indices
for x in range(len(cities)):
    try:
        print('*/'*10)
        print(f"Making request number: {x} for ID: {cities[x]}")
        the_city = cities[x]
        url = 'http://api.openweathermap.org/data/2.5/weather?q='+ the_city +'&appid='+ api_key 
        
        # Get one of the posts
        post_response = requests.get(url).json()

    except:
        print('**'*15)
        print("** can not find this root **")
        print('**'*15)
    else:
        if str(post_response['cod']) == '404':
            print(the_city +'data do not exists! :( ')
        else:
            print('the city mnumber is : '+ str(post_response['id']) +" with weather : " + post_response['weather'][0]['description'])
# Out:
# */*/*/*/*/*/*/*/*/*/
# Making request number: 0 for ID: gondanglegi
# the city mnumber is : 1640660 with weather : clear sky
# */*/*/*/*/*/*/*/*/*/
# Making request number: 1 for ID: menongue
# the city mnumber is : 3347353 with weather : clear sky
# */*/*/*/*/*/*/*/*/*/
# Making request number: 2 for ID: svay rieng
# the city mnumber is : 1821993 with weather : overcast clouds
# */*/*/*/*/*/*/*/*/*/
# Making request number: 3 for ID: labuhan
# the city mnumber is : 8079926 with weather : clear sky
# */*/*/*/*/*/*/*/*/*/
# Making request number: 4 for ID: punta arenas
# the city mnumber is : 3874787 with weather : clear sky
# */*/*/*/*/*/*/*/*/*/
# Making request number: 5 for ID: cape town
# the city mnumber is : 3369157 with weather : clear sky
# */*/*/*/*/*/*/*/*/*/
# Making request number: 6 for ID: cidreira
# the city mnumber is : 3466165 with weather : broken clouds
# */*/*/*/*/*/*/*/*/*/
# Making request number: 7 for ID: hilo
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(columns = ["City", "Lat", 'Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date']) 
weather_df
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a request for each of the indices
weather_index = 0
for x in range(len(cities)):
    try:
#         print(f"Making request number: {x} for ID: {cities[x]}")
        the_city = cities[x]
        url = 'http://api.openweathermap.org/data/2.5/weather?q='+ the_city +'&appid='+ api_key 
        
        # Get one of the posts
        post_response = requests.get(url).json()

    except:
        print('**'*15)
        print("** can not find this root **")
        print('**'*15)
    else:
        if str(post_response['cod']) == '200':
            ans_data = [post_response['name'],post_response['coord']['lat'],post_response['coord']['lon'],post_response['main']['temp_max'],post_response['main']['humidity'],post_response['clouds']['all'],post_response['wind']['speed'],post_response['sys']['country'],post_response['dt']]
            weather_df.loc[len(weather_df)] =ans_data

# %%
weather_df.head()
# Out:
#            City    Lat     Lng  Max Temp Humidity Cloudiness  Wind Speed  \
# 0   Gondanglegi  -7.75  112.01    302.50       69          0        3.19
# 1      Menongue -14.66   17.69    280.68       76          0        2.25
# 2    Svay Rieng  11.09  105.80    303.80       67         97        3.32
# 3       Labuhan  -6.88  112.21    302.55       67          0        3.14
# 4  Punta Arenas -53.15  -70.92    273.71       86          0        2.60
#
#   Country        Date
# 0      ID  1592448267
# 1      AO  1592448267
# 2      KH  1592448267
# 3      ID  1592448267
# 4      CL  1592448267

# %%
outputpath='F:/camp/hw/hw6/starter_code/output_data/citiesweather33.csv'
weather_df.to_csv(outputpath,sep=',',index=False,header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df['Humidity'].max()
# Out:
# 100

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pimentel  -6.84  -79.93     66.20        29          75        5.82
# 1  victoria  22.29  114.16     69.01        88          40       18.34
# 2    padang  -0.95  100.35     79.90        75          99        1.63
# 3    hasaki  35.73  140.83     55.00       100          75        4.70
# 4   kahului  20.89 -156.47     70.00        88           1        7.63
#
#   Country        Date
# 0      PE  1585764415
# 1      HK  1585764288
# 2      ID  1585764115
# 3      JP  1585764415
# 4      US  1585764415

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# %matplotlib notebook

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid() 
plt.title(" City Latitude vs. Max temperature ")
# The closer to the pole, the highest temperature is lowest
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, ' City Latitude vs. Max temperature ')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid() 
plt.title(" City Latitude vs. Humidity ")
# places wth higher Humidity is centered in 20-40 N, where is the location of Ocean
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, ' City Latitude vs. Humidity ')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid() 
plt.title(" City Latitude vs. Cloudiness")
plt.xlabel(" Latitude")
plt.ylabel(" Cloudiness")
# latitude ndo not show strong relationship with cloudiness, we can still know there are more clouds around 20-40 N, where the sea is.
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, ' Cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid() 
plt.title(" City Latitude vs. Wind Speed")
plt.xlabel(" Latitude")
plt.ylabel("Wind Speed")
# Wind speed pattern do not show a clear change with lat. the spend are mostly around 10-0
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_part = weather_df[weather_df['Lat']>0]
s_part = weather_df[weather_df['Lat']<0]
s_part.head()
# Out:
#         City    Lat     Lng  Max Temp Humidity Cloudiness  Wind Speed Country  \
# 0      Airai  -8.93  125.41    286.17      100         10        2.16      TL
# 2    Rikitea -23.12 -134.97    297.35       79         55        8.18      PF
# 3    Goiânia -16.68  -49.25    300.15       47         75        6.20      BR
# 5     Atuona  -9.80 -139.03    300.05       71         43        6.91      PF
# 7  Hithadhoo  -0.60   73.08    302.31       73         36        2.98      MV
#
#          Date
# 0  1592417227
# 2  1592417039
# 3  1592417132
# 5  1592417228
# 7  1592417228

# %%
plt.scatter(n_part['Lat'], n_part['Max Temp'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs. Max Temp")
plt.xlabel(" Latitude")
plt.ylabel("Max Temp")
# Add the linear regression equation and line to plot
x_values = n_part['Lat']
y_values = n_part['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,310),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In northern part, max temp decrease as the latitude increases(closer to the pole)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.5454761463207881

# %%
# Out:
# The r-squared is: 0.8271188905041935

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(s_part['Lat'], s_part['Max Temp'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
# Add the linear regression equation and line to plot
x_values = s_part['Lat']
y_values = s_part['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,280),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In southern part, max temp decrease as the latitude decreases(closer to the pole)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.6171892644781647

# %%
# Out:
# The r-squared is: 0.39936284758885965

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# n_part['Humidity'] = n_part['Humidity'].astype('float64')

# %%
n_part['Humidity'] = n_part['Humidity'].astype('float64')
x_values = n_part['Lat']
y_values = n_part['Humidity']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(n_part['Lat'], n_part['Humidity'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs.  Humidity in northern part")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Add the linear regression equation and line to plot


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,50),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In northern part, humidity decrease as the latitude decreases
# Out:
# E:\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.013493886105190766

# %%
# Out:
# The r-squared is: 0.10829462153873139

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# import pandas as pd
# s_part['Humidity'] = s_part['Humidity'].astype('float64')

# %%
x_values = s_part['Lat']
y_values = s_part['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(s_part['Lat'], s_part['Humidity'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs.  Humidity ")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Add the linear regression equation and line to plot


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In southern part, max temp decrease as the latitude decreases(closer to the pole)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.003052914834211711

# %%
# Out:
# The r-squared is: 0.0008996079328825663

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_part['Cloudiness'] = n_part['Cloudiness'].astype('float')
s_part['Cloudiness'] = s_part['Cloudiness'].astype('float')
# Out:
# E:\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# E:\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x_values = n_part['Lat']
y_values = n_part['Cloudiness']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(n_part['Lat'], n_part['Cloudiness'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs.  Cloudiness in northern part")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Add the linear regression equation and line to plot


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,50),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In northern part, cloudness do not have a clear change with lat.
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.0007619105859306149

# %%
# Out:
# The r-squared is: 0.05768812657005063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = s_part['Lat']
y_values = s_part['Cloudiness']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(s_part['Lat'], s_part['Cloudiness'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs.  Cloudiness in sorthern part")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Add the linear regression equation and line to plot


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,40),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In southern part, cloudness do not have a clear change with lat.
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.0009644936730524978

# %%
# Out:
# The r-squared is: 0.0684912094859049

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = n_part['Lat']
y_values = n_part['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(n_part['Lat'], n_part['Wind Speed'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs.  Wind Speed in northern part")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Add the linear regression equation and line to plot


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,6),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In northern part, wind speed do not have a clear change with lat.
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.005072933455385701

# %%
# Out:
# The r-squared is: 0.023371104533850804

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = s_part['Lat']
y_values = s_part['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(s_part['Lat'], s_part['Wind Speed'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(" City Latitude vs.  Wind Speed in sorthern part")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Add the linear regression equation and line to plot


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,6),fontsize=15,color="red")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# In southern part, wind speed do not have a clear change with lat.
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.002044114473104694

# %%
# Out:
# The r-squared is: 0.03381889207758188
